# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.9 MB 7.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/10.9 MB 5.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/10.9 MB 5.2 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/10.9 MB 5.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/10.9 MB 5.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.9 MB 5.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.7/10.9 MB 5.3 MB/s eta 0:00:02
# ...

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install doc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 source /venv/Scripts/activate   # On Windows
#
# NameError: name 'source' is not defined
